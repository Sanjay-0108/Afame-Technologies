# %% [markdown]
# <a href="https://colab.research.google.com/github/taniisshaa/Afame-Technologies/blob/main/HR_data_analysis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Gathering

# %%
df = pd.read_csv('C:/Users/sanja/OneDrive/Desktop/sanjay/Christ/INTERNSHIPS/Afame Technologies/Afame Technologies/HR Data.csv')

# %% [markdown]
# # Dataset Profiling

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe(include='object')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Dataset Description
# (ChatGPT Generated Description)
#
# The dataset contains information about employees in a company. Here is a description of each column:
#
# - **Age**: The age of the employee (integer).
# - **Attrition**: Whether the employee has left the company or not (object).
# - **BusinessTravel**: Frequency of business travel (object).
# - **DailyRate**: The daily rate of pay for the employee (integer).
# - **Department**: Department in which the employee works (object).
# - **DistanceFromHome**: Distance from home to work in miles (integer).
# - **Education**: Level of education of the employee (integer).
# - **EducationField**: Field of education of the employee (object).
# - **EmployeeCount**: Number of employees (always 1) (integer).
# - **EmployeeNumber**: Unique identifier for each employee (integer).
# - **EnvironmentSatisfaction**: Satisfaction level with the work environment (integer).
# - **Gender**: Gender of the employee (object).
# - **HourlyRate**: Hourly rate of pay for the employee (integer).
# - **JobInvolvement**: Level of job involvement (integer).
# - **JobLevel**: Level of job within the company (integer).
# - **JobRole**: Role of the employee in the company (object).
# - **JobSatisfaction**: Satisfaction level with the job (integer).
# - **MaritalStatus**: Marital status of the employee (object).
# - **MonthlyIncome**: Monthly income of the employee (integer).
# - **MonthlyRate**: Monthly rate of pay for the employee (integer).
# - **NumCompaniesWorked**: Number of companies the employee has worked for (integer).
# - **Over18**: Whether the employee is over 18 years old (object).
# - **OverTime**: Whether the employee works overtime or not (object).
# - **PercentSalaryHike**: Percentage increase in salary (integer).
# - **PerformanceRating**: Performance rating of the employee (integer).
# - **RelationshipSatisfaction**: Satisfaction level with work relationships (integer).
# - **StandardHours**: Standard number of working hours (always 80) (integer).
# - **StockOptionLevel**: Level of stock option (integer).
# - **TotalWorkingYears**: Total number of years worked (integer).
# - **TrainingTimesLastYear**: Number of training sessions attended last year (integer).
# - **WorkLifeBalance**: Level of work-life balance (integer).
# - **YearsAtCompany**: Number of years spent at the company (integer).
# - **YearsInCurrentRole**: Number of years in the current role (integer).
# - **YearsSinceLastPromotion**: Number of years since the last promotion (integer).
# - **YearsWithCurrManager**: Number of years with the current manager (integer).

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df['PerformanceSatisfactionIndex'] = df[['EnvironmentSatisfaction', 'JobSatisfaction', 'RelationshipSatisfaction']].mean(axis=1)

# %%
df['ExperiencePriorToCurrentJob'] = df['TotalWorkingYears'] - df['YearsAtCompany']

# %%
df['EmployeeEngagementScore'] = (df['JobInvolvement'] + df['PerformanceRating'] + df['WorkLifeBalance']) / 3

# %%
education_map = {
    1: 'Below College',
    2: 'College',
    3: 'Bachelor',
    4: 'Master',
    5: 'Doctor'
}

environment_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

job_involvement_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

job_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

performance_rating_map = {
    1: 'Low',
    2: 'Good',
    3: 'Excellent',
    4: 'Outstanding'
}

relationship_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

work_life_balance_map = {
    1: 'Bad',
    2: 'Good',
    3: 'Better',
    4: 'Best'
}

# %%
df['Education'] = df['Education'].map(education_map)
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].map(environment_satisfaction_map)
df['JobInvolvement'] = df['JobInvolvement'].map(job_involvement_map)
df['JobSatisfaction'] = df['JobSatisfaction'].map(job_satisfaction_map)
df['PerformanceRating'] = df['PerformanceRating'].map(performance_rating_map)
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].map(relationship_satisfaction_map)
df['WorkLifeBalance'] = df['WorkLifeBalance'].map(work_life_balance_map)
df['Overtime_Preference'] = df['OverTime'].map({'Yes': 1, 'No': 0})

# %%
#https://www.beresfordresearch.com/age-range-by-generation/
def generation(age):
    if (age >= 97) & (age <= 102):
        return 'WWII'
    elif (age >= 79) & (age <= 96):
        return 'Post War'
    elif (age >= 70) & (age <= 78):
        return 'Boomers I*'
    elif (age >= 60) & (age <= 69):
        return 'Boomers II (a/k/a Generation Jones)*'
    elif (age >= 44) & (age <= 59):
        return 'Gen X'
    elif (age >= 28 ) & (age <= 43):
        return 'Millennials'
    elif (age >= 12 ) & (age <= 27):
        return 'Gen Z'

# %%
def distance_category(distance):
    if (distance >= 1) & (distance <= 10):
        return 'Short Distance'
    elif (distance >= 11) & (distance <= 20):
        return 'Medium Distance'
    elif (distance >= 21) & (distance <= 30):
        return 'Long Distance'

# %%
df['AgeGeneration'] = df['Age'].apply(generation)
df['DistanceFromHomeCategory'] = df['DistanceFromHome'].apply(distance_category)

# %%
df = df.reindex(sorted(df.columns), axis=1)

# %%
df.columns
# Out:
# Index(['Age', 'AgeGeneration', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'DistanceFromHomeCategory',
#        'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeEngagementScore', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'ExperiencePriorToCurrentJob', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'Overtime_Preference', 'PercentSalaryHike',
#        'PerformanceRating', 'PerformanceSatisfactionIndex',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis (Whole Dataset)

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Age', bins=20, kde=False, color='skyblue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)

# Adding labels
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                       ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# Most of the employees recorded from this data is from 30 to 40 years old

# %%
df['Age'].median()
# Out:
# 36.0

# %%
min_age = df['Age'].min()
max_age = df['Age'].max()

print("Minimum Age:", min_age)
print("Maximum Age:", max_age)
# Out:
# Minimum Age: 18
# Maximum Age: 60

# %%
# Calculate quartiles
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)

print("IQR Min:", Q1)
print("IQR Max:", Q3)
# Out:
# IQR Min: 30.0
# IQR Max: 43.0

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Age', color='skyblue')
plt.title('Box Plot of Age Distribution')
plt.xlabel('Age')
plt.grid(True)
plt.show()

# %% [markdown]
# The box plot of the age distribution shows that the median age of employees is around 36 years old, with the interquartile range spanning from approximately 30 to 43 years old. The whiskers extend up to around 60 years old, indicating that most employees fall within this age range.

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='AgeGeneration', palette='coolwarm')
plt.title('Bar Plot of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Add count annotations to the bars
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 9),
                textcoords = 'offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\616405636.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='AgeGeneration', palette='coolwarm')

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Attrition', palette='Set1')

# Adding annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.title('Count Plot of Attrition')
plt.xlabel('Attrition')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\1855037876.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Attrition', palette='Set1')

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='BusinessTravel', palette='viridis')
plt.title('Count Plot of Business Travel')
plt.xlabel('Business Travel')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\2971219655.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='BusinessTravel', palette='viridis')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(df['DailyRate'], bins=20, kde=True, color='skyblue')

plt.title('Histogram of Daily Rate')
plt.xlabel('Daily Rate')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height:.0f}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, y='DailyRate', color='salmon')
plt.title('Box Plot of Daily Rate')
plt.ylabel('Daily Rate')

# Adding labels for key statistical values
median = df['DailyRate'].median()
q1 = df['DailyRate'].quantile(0.25)
q3 = df['DailyRate'].quantile(0.75)
min_val = df['DailyRate'].min()
max_val = df['DailyRate'].max()

# Add annotations
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Department', palette='viridis')
plt.title('Count Plot of Department')
plt.xlabel('Department')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\228287148.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Department', palette='viridis')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='DistanceFromHome', bins=20, kde=False, color='skyblue')
plt.title('Histogram of Distance from Home')
plt.xlabel('Distance from Home')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, y='DistanceFromHome', color='lightgreen')
plt.title('Box Plot of Distance from Home')
plt.ylabel('Distance from Home')

# Extracting statistical values
median = df['DistanceFromHome'].median()
q1 = df['DistanceFromHome'].quantile(0.25)
q3 = df['DistanceFromHome'].quantile(0.75)
min_val = df['DistanceFromHome'].min()
max_val = df['DistanceFromHome'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, y='DistanceFromHome', color='lightblue')

mean_distance = df['DistanceFromHome'].mean()
plt.text(0, mean_distance, f'Mean: {mean_distance:.2f}', 
         horizontalalignment='center', 
         verticalalignment='center', 
         color='black', 
         fontsize=12, 
         fontweight='bold')

plt.title('Violin Plot of Distance from Home')
plt.ylabel('Distance from Home')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Education', palette='Set2')
plt.title('Bar Plot of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

# Add annotations
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\939299729.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Education', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='EducationField', palette='pastel')
plt.title('Count Plot of Education Field')
plt.xlabel('Education Field')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\4212219493.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='EducationField', palette='pastel')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='EmployeeEngagementScore', bins=6, kde=True, color='skyblue')
plt.title('Histogram of Employee Engagement Score')
plt.xlabel('Employee Engagement Score')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='EmployeeEngagementScore', color='lightgreen')
plt.title('Box Plot of Employee Engagement Score')
plt.xlabel('Employee Engagement Score')

# Extracting statistical values
median = df['EmployeeEngagementScore'].median()
q1 = df['EmployeeEngagementScore'].quantile(0.25)
q3 = df['EmployeeEngagementScore'].quantile(0.75)
min_val = df['EmployeeEngagementScore'].min()
max_val = df['EmployeeEngagementScore'].max()

# Adding annotations for key statistical values
plt.text(median, 0, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(q3, 0, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(min_val, 0, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 0, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, x='EmployeeEngagementScore', color='lightblue')

mean_score = df['EmployeeEngagementScore'].mean()
median_score = df['EmployeeEngagementScore'].median()

plt.text(mean_score, 0, f'Mean: {mean_score:.2f}', 
         horizontalalignment='center', 
         verticalalignment='bottom', 
         color='black', 
         fontsize=12, 
         fontweight='bold')

plt.text(median_score, 0.1, f'Median: {median_score:.2f}', 
         horizontalalignment='center', 
         verticalalignment='bottom', 
         color='red', 
         fontsize=12, 
         fontweight='bold')

plt.title('Violin Plot of Employee Engagement Score')
plt.xlabel('Employee Engagement Score')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='EnvironmentSatisfaction', palette='Set1', order=['Low', 'Medium', 'High', 'Very High'])
plt.title('Count Plot of Environment Satisfaction')
plt.xlabel('Environment Satisfaction')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\943870656.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='EnvironmentSatisfaction', palette='Set1', order=['Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(df['ExperiencePriorToCurrentJob'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Experience Prior to Current Job')
plt.xlabel('Years of Experience')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(df['ExperiencePriorToCurrentJob'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Experience Prior to Current Job')
plt.xlabel('Years of Experience')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, y='ExperiencePriorToCurrentJob', color='lightblue')
plt.title('Violin Plot of Experience Prior to Current Job')
plt.ylabel('Years of Experience')

# Extracting statistical values
median = df['ExperiencePriorToCurrentJob'].median()
q1 = df['ExperiencePriorToCurrentJob'].quantile(0.25)
q3 = df['ExperiencePriorToCurrentJob'].quantile(0.75)
min_val = df['ExperiencePriorToCurrentJob'].min()
max_val = df['ExperiencePriorToCurrentJob'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Gender', palette='Set1')
plt.title('Count Plot of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\3325577204.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Gender', palette='Set1')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='HourlyRate', bins=20, kde=True, color='skyblue')
plt.title('Histogram of Hourly Rates')
plt.xlabel('Hourly Rate')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, y='HourlyRate', color='lightgreen')
plt.title('Box Plot of Hourly Rates')
plt.ylabel('Hourly Rate')

# Extracting statistical values
median = df['HourlyRate'].median()
q1 = df['HourlyRate'].quantile(0.25)
q3 = df['HourlyRate'].quantile(0.75)
min_val = df['HourlyRate'].min()
max_val = df['HourlyRate'].max()

# Adding annotations for key statistical values
plt.text(median, 0, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(q3, 0, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(min_val, 0, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 0, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, y='HourlyRate', color='skyblue')
plt.title('Violin Plot of Hourly Rates')
plt.ylabel('Hourly Rate')

# Extracting statistical values
median = df['HourlyRate'].median()
q1 = df['HourlyRate'].quantile(0.25)
q3 = df['HourlyRate'].quantile(0.75)
min_val = df['HourlyRate'].min()
max_val = df['HourlyRate'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='JobInvolvement', palette='Set1', order=['Low', 'Medium', 'High', 'Very High'])
plt.title('Count Plot of Job Involvement')
plt.xlabel('Job Involvement')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\1679665067.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='JobInvolvement', palette='Set1', order=['Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='JobLevel', palette='Set2')
plt.title('Count Plot of Job Level')
plt.xlabel('Job Level')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\674729661.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='JobLevel', palette='Set2')

# %%
plt.figure(figsize=(12, 6))
ax = sns.countplot(data=df, y='JobRole', palette='Set3')
plt.title('Count Plot of Job Roles')
plt.xlabel('Frequency')
plt.ylabel('Job Role')

for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.),
                ha='center', va='center', fontsize=10, color='black', xytext=(5, 0),
                textcoords='offset points')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\839959015.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, y='JobRole', palette='Set3')

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='JobSatisfaction', palette='Set2', order=['Low', 'Medium', 'High', 'Very High'])
plt.title('Count Plot of Job Satisfaction')
plt.xlabel('Job Satisfaction')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\1563044347.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='JobSatisfaction', palette='Set2', order=['Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='MaritalStatus', palette='Set2')
plt.title('Count Plot of Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\2662321834.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='MaritalStatus', palette='Set2')

# %%
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(df['MonthlyIncome'], bins=20, kde=True, color='skyblue')
plt.title('Histogram of Monthly Income')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='MonthlyIncome', color='skyblue')
plt.title('Box Plot of Monthly Income')
plt.xlabel('Monthly Income')

# Extracting statistical values
median = df['MonthlyIncome'].median()
q1 = df['MonthlyIncome'].quantile(0.25)
q3 = df['MonthlyIncome'].quantile(0.75)
min_val = df['MonthlyIncome'].min()
max_val = df['MonthlyIncome'].max()

# Adding annotations for key statistical values
plt.text(median, 0, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(q3, 0, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(min_val, 0, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 0, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(10, 6))
violin_plot = sns.violinplot(data=df, y='MonthlyIncome', color='skyblue')
plt.title('Violin Plot of Monthly Income')
plt.ylabel('Monthly Income')

# Extracting statistical values
median = df['MonthlyIncome'].median()
q1 = df['MonthlyIncome'].quantile(0.25)
q3 = df['MonthlyIncome'].quantile(0.75)
min_val = df['MonthlyIncome'].min()
max_val = df['MonthlyIncome'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(df['MonthlyRate'], bins=20, kde=True, color='salmon')
plt.title('Histogram of Monthly Rate')
plt.xlabel('Monthly Rate')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='MonthlyRate', color='salmon')
plt.title('Box Plot of Monthly Rate')
plt.xlabel('Monthly Rate')

# Extracting statistical values
median = df['MonthlyRate'].median()
q1 = df['MonthlyRate'].quantile(0.25)
q3 = df['MonthlyRate'].quantile(0.75)
min_val = df['MonthlyRate'].min()
max_val = df['MonthlyRate'].max()

# Adding annotations for key statistical values
plt.text(median, 0, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(q3, 0, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(min_val, 0, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 0, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(10, 6))
violin_plot = sns.violinplot(data=df, y='MonthlyRate', color='salmon')
plt.title('Violin Plot of Monthly Rate')
plt.ylabel('Monthly Rate')

# Extracting statistical values
median = df['MonthlyRate'].median()
q1 = df['MonthlyRate'].quantile(0.25)
q3 = df['MonthlyRate'].quantile(0.75)
min_val = df['MonthlyRate'].min()
max_val = df['MonthlyRate'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(df['NumCompaniesWorked'], bins=10, kde=True, color='skyblue')
plt.title('Histogram of Number of Companies Worked')
plt.xlabel('Number of Companies Worked')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='NumCompaniesWorked', color='skyblue')
plt.title('Box Plot of Number of Companies Worked')
plt.xlabel('Number of Companies Worked')

# Extracting statistical values
median = df['NumCompaniesWorked'].median()
q1 = df['NumCompaniesWorked'].quantile(0.25)
q3 = df['NumCompaniesWorked'].quantile(0.75)
min_val = df['NumCompaniesWorked'].min()
max_val = df['NumCompaniesWorked'].max()

# Adding annotations for key statistical values
plt.text(median, 0, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(q3, 0, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(min_val, 0, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 0, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(10, 6))
violin_plot = sns.violinplot(data=df, y='NumCompaniesWorked', color='skyblue')
plt.title('Violin Plot of Number of Companies Worked')
plt.ylabel('Number of Companies Worked')

# Extracting statistical values
median = df['NumCompaniesWorked'].median()
q1 = df['NumCompaniesWorked'].quantile(0.25)
q3 = df['NumCompaniesWorked'].quantile(0.75)
min_val = df['NumCompaniesWorked'].min()
max_val = df['NumCompaniesWorked'].max()

# Adding annotations for key statistical values
plt.text(0, median, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(0, q1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, q3, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(0, min_val, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(0, max_val, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Over18', palette='Set1')
plt.title('Count Plot of Over 18')
plt.xlabel('Over 18')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

# Adding annotations
for p in ax.patches:
    height = p.get_height()
    x = p.get_x() + p.get_width() / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\4104406633.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Over18', palette='Set1')

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='OverTime', palette='Set1')
plt.title('Count Plot of Overtime Preference')
plt.xlabel('Overtime Preference')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\2668225106.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='OverTime', palette='Set1')

# %%
plt.figure(figsize=(10, 6))
hist_plot = sns.histplot(data=df, x='PercentSalaryHike', bins=15, kde=True, color='skyblue')
plt.title('Histogram of Percent Salary Hike')
plt.xlabel('Percent Salary Hike')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='PercentSalaryHike', color='lightcoral')
plt.title('Box Plot of Percent Salary Hike')
plt.xlabel('Percent Salary Hike')

# Extracting statistical values
median = df['PercentSalaryHike'].median()
q1 = df['PercentSalaryHike'].quantile(0.25)
q3 = df['PercentSalaryHike'].quantile(0.75)
min_val = df['PercentSalaryHike'].min()
max_val = df['PercentSalaryHike'].max()

# Adding annotations for key statistical values
plt.text(median, 1, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(q3, 1, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(min_val, 1, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 1, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='PerformanceRating', palette='pastel')
plt.title('Count Plot of Performance Rating')
plt.xlabel('Performance Rating')
plt.ylabel('Frequency')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\760365129.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='PerformanceRating', palette='pastel')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='PerformanceSatisfactionIndex', bins=10, kde=True, color='skyblue')
plt.title('Histogram of Performance Satisfaction Index')
plt.xlabel('Performance Satisfaction Index')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, y='PerformanceSatisfactionIndex', color='lightgreen')
plt.title('Box Plot of Performance Satisfaction Index')
plt.ylabel('Performance Satisfaction Index')
plt.show()

# %%
plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, y='PerformanceSatisfactionIndex', color='salmon')
plt.title('Violin Plot of Performance Satisfaction Index')
plt.ylabel('Performance Satisfaction Index')

# Extracting statistical values
median = df['PerformanceSatisfactionIndex'].median()
q1 = df['PerformanceSatisfactionIndex'].quantile(0.25)
q3 = df['PerformanceSatisfactionIndex'].quantile(0.75)
min_val = df['PerformanceSatisfactionIndex'].min()
max_val = df['PerformanceSatisfactionIndex'].max()

# Adding annotations for key statistical values
plt.text(median, 1, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 1, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(q3, 1, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(min_val, 1, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='bottom', fontdict={'size': 10}, color='black')
plt.text(max_val, 1, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='top', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='RelationshipSatisfaction', palette='pastel', order=['Low', 'Medium', 'High', 'Very High'])
plt.title('Count Plot of Relationship Satisfaction')
plt.xlabel('Relationship Satisfaction')
plt.ylabel('Frequency')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\677089270.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='RelationshipSatisfaction', palette='pastel', order=['Low', 'Medium', 'High', 'Very High'])

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='StandardHours', palette='Set2')
plt.title('Count Plot of Standard Hours')
plt.xlabel('Standard Hours')
plt.ylabel('Frequency')

# Adding annotations
for p in ax.patches:
    height = p.get_height()
    x = p.get_x() + p.get_width() / 2
    plt.text(x, height, f'{height}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_9488\838578344.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='StandardHours', palette='Set2')

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='StockOptionLevel', palette='Set3')
plt.title('Count Plot of Stock Option Level')
plt.xlabel('Stock Option Level')
plt.ylabel('Frequency')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\1409830557.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='StockOptionLevel', palette='Set3')

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='TotalWorkingYears')
plt.title('Box Plot of Total Working Years')
plt.xlabel('Total Working Years')

# Extracting statistical values
median = df['TotalWorkingYears'].median()
q1 = df['TotalWorkingYears'].quantile(0.25)
q3 = df['TotalWorkingYears'].quantile(0.75)
min_val = df['TotalWorkingYears'].min()
max_val = df['TotalWorkingYears'].max()

# Adding annotations for key statistical values
plt.text(median, 1.05, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 1.05, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(q3, 1.05, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(min_val, 1.05, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(max_val, 1.05, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='TotalWorkingYears', bins=10, kde=True)
plt.title('Histogram of Total Working Years')
plt.xlabel('Total Working Years')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{int(height)}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='TrainingTimesLastYear', bins=7, kde=True)
plt.title('Histogram of Training Times Last Year')
plt.xlabel('Training Times Last Year')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{int(height)}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
violin_plot = sns.violinplot(data=df, y='TrainingTimesLastYear')

mean_training_times = df['TrainingTimesLastYear'].mean()
median_training_times = df['TrainingTimesLastYear'].median()


plt.text(mean_training_times, 0, f'Mean: {mean_training_times:.2f}', 
         horizontalalignment='center', 
         verticalalignment='bottom', 
         color='black', 
         fontsize=12, 
         fontweight='bold')

plt.text(median_training_times, 0.1, f'Median: {median_training_times:.2f}', 
         horizontalalignment='center', 
         verticalalignment='bottom', 
         color='red', 
         fontsize=12, 
         fontweight='bold')

plt.title('Violin Plot of Training Times Last Year')
plt.ylabel('Training Times Last Year')

plt.show()

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='WorkLifeBalance', palette='Set2')
plt.title('Bar Plot of Work-Life Balance')
plt.xlabel('Work-Life Balance')
plt.ylabel('Frequency')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\858498957.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='WorkLifeBalance', palette='Set2')

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='YearsAtCompany', bins=20, kde=True)
plt.title('Histogram of Years at Company')
plt.xlabel('Years at Company')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{int(height)}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(data=df, x='YearsAtCompany')

plt.title('Box Plot of Years at Company')
plt.xlabel('Years at Company')

# Extracting statistical values
median = df['YearsAtCompany'].median()
q1 = df['YearsAtCompany'].quantile(0.25)
q3 = df['YearsAtCompany'].quantile(0.75)
min_val = df['YearsAtCompany'].min()
max_val = df['YearsAtCompany'].max()

# Adding annotations for key statistical values
plt.text(median, 0.5, f'Median: {median:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10, 'weight': 'bold'}, color='black')
plt.text(q1, 0.5, f'Q1: {q1:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(q3, 0.5, f'Q3: {q3:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(min_val, 0.5, f'Min: {min_val:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')
plt.text(max_val, 0.5, f'Max: {max_val:.2f}', horizontalalignment='center', verticalalignment='center', fontdict={'size': 10}, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
hist_plot = sns.histplot(data=df, x='YearsInCurrentRole', bins=19, kde=True)
plt.title('Histogram of Years in Current Role')
plt.xlabel('Years in Current Role')
plt.ylabel('Frequency')

# Adding annotations
for p in hist_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    plt.text(x, height, f'{int(height)}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='YearsInCurrentRole')
plt.title('Box Plot of Years in Current Role')
plt.xlabel('Years in Current Role')
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Create the histogram
ax = sns.histplot(data=df, x='YearsSinceLastPromotion', bins=16, kde=True)

# Add data labels
for patch in ax.patches:
    height = patch.get_height()
    if height > 0:  # Only label non-zero heights
        ax.annotate(f'{int(height)}',
                    (patch.get_x() + patch.get_width() / 2., height),
                    ha='center', va='center', fontsize=9, color='black',
                    xytext=(0, 5), textcoords='offset points')

# Add titles and labels
plt.title('Histogram of Years Since Last Promotion')
plt.xlabel('Years Since Last Promotion')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='YearsSinceLastPromotion')
plt.title('Box Plot of Years Since Last Promotion')
plt.xlabel('Years Since Last Promotion')
plt.show()

# %%
plt.figure(figsize=(8, 6))

# Create the histogram
ax = sns.histplot(data=df, x='YearsWithCurrManager', bins=18, kde=True)

# Add data labels
for patch in ax.patches:
    height = patch.get_height()
    if height > 0:  # Only label non-zero heights
        ax.annotate(f'{int(height)}',
                    (patch.get_x() + patch.get_width() / 2., height),
                    ha='center', va='center', fontsize=9, color='black',
                    xytext=(0, 5), textcoords='offset points')

# Add titles and labels
plt.title('Histogram of Years With Current Manager')
plt.xlabel('Years With Current Manager')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='YearsWithCurrManager')
plt.title('Box Plot of Years With Current Manager')
plt.xlabel('Years With Current Manager')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(10, 6))

age_generations = df['AgeGeneration'].unique()
# Define colors for each age group for better visibility
colors = sns.color_palette('coolwarm', len(age_generations))

for i, age_group in enumerate(age_generations):
    data = df[df['AgeGeneration'] == age_group]['Age']
    ax = sns.histplot(data, kde=False, label=age_group, bins=20, color=colors[i], alpha=0.5)
    
    # Add data labels
    for patch in ax.patches:
        height = patch.get_height()
        if height > 0:  # Only label non-zero heights
            ax.annotate(f'{int(height)}', 
                        (patch.get_x() + patch.get_width() / 2., height), 
                        ha='center', va='center', fontsize=9, color='black', 
                        xytext=(0, 5), textcoords='offset points')

plt.title('Histogram of Age Groups')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend(title='Age Group')
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='AgeGeneration', y='Age', palette='coolwarm')
plt.title('Box Plot of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\544742285.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='AgeGeneration', y='Age', palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='AgeGeneration', y='Age', palette='coolwarm')
plt.title('Violin Plot of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_32152\4251415605.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='AgeGeneration', y='Age', palette='coolwarm')

# %%
plt.figure(figsize=(8, 6))
box_plot = sns.boxplot(x='Attrition', y='Age', data=df)
plt.title('Attrition vs. Age')
plt.xlabel('Attrition')
plt.ylabel('Age')

# Adding annotations
for i, artist in enumerate(box_plot.artists):
   
    box_data = df[df['Attrition'] == box_plot.get_xticklabels()[i].get_text()]['Age']
    median = box_data.median()
    
    plt.text(i, median, f'Median: {median:.1f}', ha='center', va='center', fontsize=10, color='black', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(10, 6))
box_plot = sns.boxplot(data=df, x='Department', y='Age')
plt.title('Age vs. Department')
plt.xlabel('Department')
plt.ylabel('Age')

# Adding annotations
for i, artist in enumerate(box_plot.artists):
    # Extracting the properties of each box
    box_data = df[df['Department'] == box_plot.get_xticklabels()[i].get_text()]['Age']
    median = box_data.median()
    q1 = box_data.quantile(0.25)
    q3 = box_data.quantile(0.75)
    
  
    plt.text(i, median, f'Median: {median:.1f}', ha='center', va='center', fontsize=10, color='black', xytext=(0, 10), textcoords='offset points')
    plt.text(i, q1, f'Q1: {q1:.1f}', ha='center', va='center', fontsize=10, color='black', xytext=(0, 10), textcoords='offset points')
    plt.text(i, q3, f'Q3: {q3:.1f}', ha='center', va='center', fontsize=10, color='black', xytext=(0, 10), textcoords='offset points')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='MonthlyIncome', y='Age')
plt.title('Age vs. Monthly Income')
plt.xlabel('Monthly Income')
plt.ylabel('Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
count_plot = sns.countplot(x='Attrition', hue='Gender', data=df, palette='Set1')
plt.title('Attrition by Gender')
plt.xlabel('Attrition')
plt.ylabel('Count')

# Adding annotations
for p in count_plot.patches:
    height = p.get_height()
    width = p.get_width()
    x = p.get_x() + width / 2
    y = p.get_y() + height
    plt.text(x, y, f'{int(height)}', ha='center', va='bottom', fontsize=10, color='black')

plt.show()
